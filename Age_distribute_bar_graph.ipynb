# %% [markdown]
# <a href="https://colab.research.google.com/github/Surveh18/AI-ML-PRACTICALS/blob/main/Age_distribute_bar_graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("tested.csv")

# %%
titanic_data = df.dropna(subset=['Age'])

# %%
plt.figure(figsize=(10,6))
plt.hist(titanic_data['Age'], bins=20, color='skyblue', edgecolor='black')
plt.title('Age Distribution of Titanic Passengers')
plt.xlabel('Age')
plt.ylabel('Count')
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()
